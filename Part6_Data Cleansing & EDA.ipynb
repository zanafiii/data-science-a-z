# %% [markdown]
# # Part6_Data Cleansing & EDA

# %% [markdown]
# ## Data Cleansing

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    "cust_id" : ["C1","C2","C3","C4","C5","C6","C7","C8","C9","C10","C11"],
    "item_bought" : [10,7,5,4,10000,10,5,5,7, np.nan, np.nan],
    "city" : ["Bandung", "Jakarta", "Bogor", "Tangerang", "Bandung", "Bogor", "Bogor", "Bogor", "Bandung", "Jakarta", np.nan]
})

df
# Out:
#    cust_id  item_bought       city
# 0       C1         10.0    Bandung
# 1       C2          7.0    Jakarta
# 2       C3          5.0      Bogor
# 3       C4          4.0  Tangerang
# 4       C5      10000.0    Bandung
# 5       C6         10.0      Bogor
# 6       C7          5.0      Bogor
# 7       C8          5.0      Bogor
# 8       C9          7.0    Bandung
# 9      C10          NaN    Jakarta
# 10     C11          NaN        NaN

# %%
## Check Missing Values

df.isna().sum()
# Out:
# cust_id        0
# item_bought    2
# city           1
# dtype: int64

# %%
## Handle Missing Values

# %%
## Drop

df.dropna()
# Out:
#   cust_id  item_bought       city
# 0      C1         10.0    Bandung
# 1      C2          7.0    Jakarta
# 2      C3          5.0      Bogor
# 3      C4          4.0  Tangerang
# 4      C5      10000.0    Bandung
# 5      C6         10.0      Bogor
# 6      C7          5.0      Bogor
# 7      C8          5.0      Bogor
# 8      C9          7.0    Bandung

# %%
df
# Out:
#    cust_id  item_bought       city
# 0       C1         10.0    Bandung
# 1       C2          7.0    Jakarta
# 2       C3          5.0      Bogor
# 3       C4          4.0  Tangerang
# 4       C5      10000.0    Bandung
# 5       C6         10.0      Bogor
# 6       C7          5.0      Bogor
# 7       C8          5.0      Bogor
# 8       C9          7.0    Bandung
# 9      C10          NaN    Jakarta
# 10     C11          NaN        NaN

# %%
## Fill

# %%
## Numeric

df_clean = df.copy()
df_clean["item_bought"] = df["item_bought"].fillna(0)
df_clean
# Out:
#    cust_id  item_bought       city
# 0       C1         10.0    Bandung
# 1       C2          7.0    Jakarta
# 2       C3          5.0      Bogor
# 3       C4          4.0  Tangerang
# 4       C5      10000.0    Bandung
# 5       C6         10.0      Bogor
# 6       C7          5.0      Bogor
# 7       C8          5.0      Bogor
# 8       C9          7.0    Bandung
# 9      C10          0.0    Jakarta
# 10     C11          0.0        NaN

# %%
df_clean = df.copy()
df_clean["item_bought"] = df["item_bought"].fillna(df["item_bought"].mean())
df_clean
# Out:
#    cust_id  item_bought       city
# 0       C1         10.0    Bandung
# 1       C2          7.0    Jakarta
# 2       C3          5.0      Bogor
# 3       C4          4.0  Tangerang
# 4       C5      10000.0    Bandung
# 5       C6         10.0      Bogor
# 6       C7          5.0      Bogor
# 7       C8          5.0      Bogor
# 8       C9          7.0    Bandung
# 9      C10       1117.0    Jakarta
# 10     C11       1117.0        NaN

# %%
df_clean = df.copy()
df_clean["item_bought"] = df["item_bought"].fillna(df["item_bought"].median())
df_clean
# Out:
#    cust_id  item_bought       city
# 0       C1         10.0    Bandung
# 1       C2          7.0    Jakarta
# 2       C3          5.0      Bogor
# 3       C4          4.0  Tangerang
# 4       C5      10000.0    Bandung
# 5       C6         10.0      Bogor
# 6       C7          5.0      Bogor
# 7       C8          5.0      Bogor
# 8       C9          7.0    Bandung
# 9      C10          7.0    Jakarta
# 10     C11          7.0        NaN

# %%
## Categorical

df_clean = df.copy()
df_clean["city"] = df["city"].fillna(df["city"].modus())
df_clean
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 4
#       1 ## Categorical
#       3 df_clean = df.copy()
# ----> 4 df_clean["city"] = df["city"].fillna(df["city"].modus())
#       5 df_clean
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'modus'
